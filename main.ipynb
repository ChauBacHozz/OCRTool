# %%
from qwen_ocr_viet import ocr_vietnamese

# %%
img_path = "test_AI/AnhGiayPhep_1_111436_2026557229641.jpg"

# %%
res = ocr_vietnamese(img_path)

# %%
print(res)
# Out:
# so_giay_phep='125/2023/GPP-QT' loai_giay_phep='GIẤY CHỨNG NHẬN ĐẠT THỰC HÀNH TỐT CƠ SỞ BÁN LẺ THUỐC GOOD PHARMACY PRACTICES (GPP)' hieuluc='Giấy chứng nhận này có giá trị ba năm kể từ ngày ký.' coso='CƠ SỞ: QUẦY THUỐC THẮNG HÀNH. Trụ sở: Xóm 3, Xã Kim Chính, Huyện Kim Sơn, Tỉnh Ninh Bình.'
